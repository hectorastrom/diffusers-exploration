# %% [markdown]
# # Visualize dataset
#
# ### Purpose: test functions in clip_classifier w/ visuals

# %%
from datasets import DatasetDict
from clip_classifier import load_cod10k_lazy
from IPython.display import display

dataset : DatasetDict = load_cod10k_lazy()
# Out:
# Encoding labels...

# %%
all_labels = dataset['train'].features['label'].names
sample = dataset['train'][0]
class_idx = sample['label']
all_labels[class_idx]
# Out:
# 'BatFish'

# %%
image_pil = sample['image_path']
display(image_pil)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600>
